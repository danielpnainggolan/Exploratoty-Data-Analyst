# %% [markdown]
# ### Homework Rakamin Trial Class - Mini Case

# %% [markdown]
# # Mengukur Performa Penjualan Ritel Online

# %% [markdown]
# ## Load Data

# %%
import pandas as pd
df_dataset = pd.read_csv('online_retail_II.csv')

# %%
df_dataset
# Out:
#         Invoice StockCode  ... Customer ID         Country
# 0        489434     85048  ...     13085.0  United Kingdom
# 1        489434    79323P  ...     13085.0  United Kingdom
# 2        489434    79323W  ...     13085.0  United Kingdom
# 3        489434     22041  ...     13085.0  United Kingdom
# 4        489434     21232  ...     13085.0  United Kingdom
# ...         ...       ...  ...         ...             ...
# 1067366  581587     22899  ...     12680.0          France
# 1067367  581587     23254  ...     12680.0          France
# 1067368  581587     23255  ...     12680.0          France
# 1067369  581587     22138  ...     12680.0          France
# 1067370  581587      POST  ...     12680.0          France
#
# [1067371 rows x 8 columns]

# %%
df_dataset.shape
# Out:
# (1067371, 8)

# %%
df_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067371 entries, 0 to 1067370
# Data columns (total 8 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   Invoice      1067371 non-null  object
#  1   StockCode    1067371 non-null  object
#  2   Description  1062989 non-null  object
#  3   Quantity     1067371 non-null  int64
#  4   InvoiceDate  1067371 non-null  object
#  5   Price        1067371 non-null  float64
#  6   Customer ID  824364 non-null   float64
#  7   Country      1067371 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 65.1+ MB

# %%
df_dataset.nunique()
# Out:
# Invoice        53628
# StockCode       5305
# Description     5698
# Quantity        1057
# InvoiceDate    47635
# Price           2807
# Customer ID     5942
# Country           43
# dtype: int64

# %%
df_dataset.isnull().sum()
# Out:
# Invoice             0
# StockCode           0
# Description      4382
# Quantity            0
# InvoiceDate         0
# Price               0
# Customer ID    243007
# Country             0
# dtype: int64

# %%
# Out:
# (1067371, 8)

# %% [markdown]
# ## Section 1

# %% [markdown]
# ### Create New Feature: Year

# %%
df_dataset['InvoiceDate']
df_dataset['Year'] = pd.DatetimeIndex(df_dataset['InvoiceDate']).year
df_dataset
# Out:
#         Invoice StockCode  ...         Country  Year
# 0        489434     85048  ...  United Kingdom  2009
# 1        489434    79323P  ...  United Kingdom  2009
# 2        489434    79323W  ...  United Kingdom  2009
# 3        489434     22041  ...  United Kingdom  2009
# 4        489434     21232  ...  United Kingdom  2009
# ...         ...       ...  ...             ...   ...
# 1067366  581587     22899  ...          France  2011
# 1067367  581587     23254  ...          France  2011
# 1067368  581587     23255  ...          France  2011
# 1067369  581587     22138  ...          France  2011
# 1067370  581587      POST  ...          France  2011
#
# [1067371 rows x 9 columns]

# %% [markdown]
# ### Filtering Data

# %%
sales= df_dataset[(df_dataset['Quantity']>=1) & (~df_dataset['Invoice'].str.contains('C'))]
sales
# Out:
#         Invoice StockCode  ...         Country  Year
# 0        489434     85048  ...  United Kingdom  2009
# 1        489434    79323P  ...  United Kingdom  2009
# 2        489434    79323W  ...  United Kingdom  2009
# 3        489434     22041  ...  United Kingdom  2009
# 4        489434     21232  ...  United Kingdom  2009
# ...         ...       ...  ...             ...   ...
# 1067366  581587     22899  ...          France  2011
# 1067367  581587     23254  ...          France  2011
# 1067368  581587     23255  ...          France  2011
# 1067369  581587     22138  ...          France  2011
# 1067370  581587      POST  ...          France  2011
#
# [1044420 rows x 9 columns]

# %% [markdown]
# ### Create New Feature: Revenue

# %%
df_dataset['Revenue'] = df_dataset[ "Quantity"] * df_dataset['Price']
df_dataset
# Out:
#         Invoice StockCode  ...  Year  Revenue
# 0        489434     85048  ...  2009    83.40
# 1        489434    79323P  ...  2009    81.00
# 2        489434    79323W  ...  2009    81.00
# 3        489434     22041  ...  2009   100.80
# 4        489434     21232  ...  2009    30.00
# ...         ...       ...  ...   ...      ...
# 1067366  581587     22899  ...  2011    12.60
# 1067367  581587     23254  ...  2011    16.60
# 1067368  581587     23255  ...  2011    16.60
# 1067369  581587     22138  ...  2011    14.85
# 1067370  581587      POST  ...  2011    18.00
#
# [1067371 rows x 10 columns]

# %% [markdown]
# ### Average of Revenue per Year

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_dataset.groupby('Year')['Revenue'].mean().reset_index().plot(x="Year", y="Revenue", kind="bar", rot=3, fontsize=4)

# %% [markdown]
# ### Interpretation

# %% [markdown]
# Dari hasil yang telah diperoleh,dapat disimpulkan bahwa total revenue tertinggi berapa pada tahun 2010, kemudian diikuti pada tahun 2011 dan 2009

# %% [markdown]
# ## Section 2

# %% [markdown]
# ### Filtering Data

# %% [markdown]
# #### Customers who finished their purchases

# %%
finished = df_dataset.loc[df_dataset['Customer ID'].notnull()]
finished
# Out:
#         Invoice StockCode  ...  Year  Revenue
# 0        489434     85048  ...  2009    83.40
# 1        489434    79323P  ...  2009    81.00
# 2        489434    79323W  ...  2009    81.00
# 3        489434     22041  ...  2009   100.80
# 4        489434     21232  ...  2009    30.00
# ...         ...       ...  ...   ...      ...
# 1067366  581587     22899  ...  2011    12.60
# 1067367  581587     23254  ...  2011    16.60
# 1067368  581587     23255  ...  2011    16.60
# 1067369  581587     22138  ...  2011    14.85
# 1067370  581587      POST  ...  2011    18.00
#
# [824364 rows x 10 columns]

# %% [markdown]
# #### Customers who canceled their purchases

# %%
cancel = df_dataset[(df_dataset['Invoice'].str.contains('C'))]
cancel
# Out:
#          Invoice StockCode  ...  Year  Revenue
# 178      C489449     22087  ...  2009   -35.40
# 179      C489449    85206A  ...  2009    -9.90
# 180      C489449     21895  ...  2009   -17.00
# 181      C489449     21896  ...  2009   -12.60
# 182      C489449     22083  ...  2009   -35.40
# ...          ...       ...  ...   ...      ...
# 1065910  C581490     23144  ...  2011    -9.13
# 1067002  C581499         M  ...  2011  -224.69
# 1067176  C581568     21258  ...  2011   -54.75
# 1067177  C581569     84978  ...  2011    -1.25
# 1067178  C581569     20979  ...  2011    -6.25
#
# [19494 rows x 10 columns]

# %% [markdown]
# ### Number of Finished and Canceled Transactions Each Year

# %%
finished.groupby('Year')['Invoice'].count().reset_index().plot(x="Year", y="Invoice", kind="bar", rot=3, fontsize=4)

# %%
cancel.groupby('Year')['Invoice'].count().reset_index().plot(x="Year", y="Invoice", kind="bar", rot=3, fontsize=4)

# %% [markdown]
# ### Cancellation Rate

# %%
rate = cancel.shape[0] / df_dataset[(df_dataset['Customer ID']).notnull()].shape[0]
rate
# Out:
# 0.023647320843704966

# %% [markdown]
# ### Interpretation

# %% [markdown]
# Data jumlah customer yang melakukan pembatalan order pada tahun 2009 ke tahun 2010 naik secara signifikan. Sehingga rating customer yang melakukan pembatalan sebesar 0.02 tersebut tidak cocok untuk melambangkan grafik kenaikan pembatanan order dari tahun 2009 ke tahun 2010
